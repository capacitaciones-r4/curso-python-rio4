# %% [markdown]
# # Repaso de Clase 1
#
# ## Estructuras de control de flujo
#
# Las estructuras de control de flujo son sentencias que permiten *controlar* el flujo de un programa en función de alguna condición. Se puede ejecutar de manera *no secuencial* una serie de instrucciones a seguir por el intérprete de Python, "tomando decisiones" sobre el flujo del programa, según el resultado de evaluar condiciones.
#
# * **if elif y else**: Se usa para una instrucción condicional, si la condición se cumple (`True`), se ejecuta determinada instrucción, de lo contrario (`False`), una instrucción diferente.
# * **for**: Se realiza de manera repetitiva una instrucción, siempre que se conozca o se pueda calcular, exactamente el número de veces que se debe repetir.
# * **while**: Se realiza de manera repetitiva una instrucción, mientras se cumpla determinada condición (`True`), en cuanto dicha condición cambie y/o se produzca un evento, se deja de ejecutar la instrucción.
# * **try/except**: Intenta realizar una instrucción, si la misma produce un error lo *"ataja"*, se ejecuta el bloque "except".

# %% [markdown]
# ### If
#
# **EJERCICIO 26**: Dada la lista de `caballeros de la mesa cuadrada`, si "Sir Lancelot" se encuentra en la lista, escribir por pantalla "¡Bienvenido, valiente sir Lancelot!", si Sir Lancelot no se encuentra en la lista, pero Sir Robin si, escribir por pantalla "¡Bienvenido Sir Robin, no tan valiente como Lancelot!".
#
# Implementar el código con las dos listas a continuación:

# %%
caballeros = [
    'Arthur, King of the Britons',
    'Sir Lancelot the Brave',
    "Patsy, Arthur's Servant",
    'Sir Robin the Not-Quite-So-Brave-as-Sir-Lancelot'
]

# %%
caballeros_2 = [
    'Arthur, King of the Britons',
    'Sir Bedevere the Wise',
    "Patsy, Arthur's Servant",
    'Sir Robin the Not-Quite-So-Brave-as-Sir-Lancelot'
]

# %% [markdown]
# ### For
#
# **EJERCICIO 27**: Para las listas antes mencionadas, imprimir por pantalla un saludo para *cada caballero*, por ejemplo `Bienvenido, Arthur, King of the Britons`

# %% [markdown]
# ### While
#
# **EJERCICIO 28**: Se desea nombrar a los caballeros de la mesa redonda en un post de una red social que tiene como límite `50 caracteres`, mientras la longitud de los strings de los caballeros no supere dicho número, imprimir el nombre del caballero, de lo contrario, imprimir "Límite de caracteres alcanzado".

# %% [markdown]
# ### Opcional
# **EJERCICIO 28 bis**:  Para las listas de caballeros se pide:
# - Juntarlas en una sola lista, remover los duplicados.
# - Recorrer la lista, y saludar:
#   - Al valiente "Sir Lancelot".
#   - Al no-tan-valiente "Sir Robin".
#   - Un saludo generico para los demas.
#   - Y por ultimo, si encontramos a "Patsy" (que no es un caballero), removerlo de la lista.
